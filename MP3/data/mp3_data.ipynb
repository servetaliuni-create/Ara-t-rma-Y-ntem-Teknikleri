# %%
import pandas as pd

# CSV dosyasını oku
# Dosyayı az önce Colab ortamına yüklediğimiz için direkt adıyla okuyabiliriz.
df = pd.read_csv('data.mp3.csv')

# İlk 5 satırı göster
print("Çalışma 1 Veri Seti (İçsel Faktörler):")
print(df.head())
# Out:
# Çalışma 1 Veri Seti (İçsel Faktörler):
#    gonderi_id     format  kaydetme_sayisi  begeni_sayisi  yorum_sayisi  \
# 0           1       Reel              150            800            40
# 1           2   Carousel              350            600            80
# 2           3  TekGorsel               50            450            20
# 3           4       Reel              210           1100            65
# 4           5   Carousel              410            750            90
#
#    paylasim_sayisi  organik_erisim  kesfet_erisim
# 0               50           12000           9500
# 1              120            9000           6000
# 2               10            3500            500
# 3               70           18000          15000
# 4              150           11500           8000

# %% [markdown]
# # MP3 - Veri Toplama Açıklaması
#
# ## 1. Çalışma (İçsel Faktörler): `data.mp3.csv`
#
# * **Yöntem:** Gözlem veya Deneysel Ölçüm
# * **Açıklama:** Bu veri seti, "Kaydetme vs. Beğeni" hipotezini test etmek için oluşturulmuş örnek bir veri dosyasıdır. Gerçek çalışmada, kendi 240K takipçili Instagram sayfamın "Insights" (İstatistikler) panelinden son 3 aya ait gönderilerin verileri manuel olarak toplanacak ve bu CSV dosyasına işlenecektir.
# * **Sütunlar:** `gonderi_id`, `format` (Reel, Carousel, TekGorsel), `kaydetme_sayisi`, `begeni_sayisi`, `yorum_sayisi`, `paylasim_sayisi`, `organik_erisim` (Toplam erişim), `kesfet_erisim` (Keşfet'ten gelen erişim).
#
# ## 2. Çalışma (Dışsal Faktörler):
#
# * **Yöntem:** Gözlem (Deneysel) ve Anket (Google Forms)
# * **Açıklama:** Bu çalışma için veri toplama işlemi iki aşamalı olacaktır:
#     1.  **Kişisel Deney (Gözlem):** Spesifik bir konuda (örn: "Japonya uçak bileti") 1 gün boyunca Google araması yapılacak ve Instagram Keşfet akışı 3 gün boyunca gözlemlenerek, bu konuyla ilgili *organik* içeriklerin (reklam değil) çıkma sıklığı ve hızı not edilecektir.
#     2.  **Katılımcı Deneyi (Anket):** 10-15 kişilik bir katılımcı grubuna bir Google Formu gönderilecektir. Katılımcılardan benzer bir deneyi yapmaları ve sonuçları (ilgili içerik görüp görmedikleri, ne kadar süre sonra gördükleri) forma işlemeleri istenecektir. Bu veriler ayrı bir CSV olarak toplanacaktır.

# %%
# %%writefile data.mp3.csv
# gonderi_id,format,kaydetme_sayisi,begeni_sayisi,yorum_sayisi,paylasim_sayisi,organik_erisim,kesfet_erisim
# 001,Reel,150,800,40,50,12000,9500
# 002,Carousel,350,600,80,120,9000,6000
# 003,TekGorsel,50,450,20,10,3500,500
# 004,Reel,210,1100,65,70,18000,15000
# 005,Carousel,410,750,90,150,11500,8000
# 006,Reel,180,920,55,60,14000,11000
# 007,TekGorsel,70,510,25,15,4000,700
# 008,Carousel,380,680,85,130,10000,7500
# 009,Reel,250,1300,75,80,22000,19000
# 010,Carousel,450,820,100,160,13000,9200
# 011,Reel,190,950,60,65,15500,12000
# 012,TekGorsel,65,480,22,12,3800,600
# 013,Carousel,390,710,95,140,11000,8100
# 014,Reel,230,1150,70,75,19500,16000
# 015,Carousel,430,790,98,155,12500,8800
# 016,Reel,175,880,58,62,13000,10000
# 017,TekGorsel,80,530,28,18,4500,850
# 018,Carousel,400,730,92,145,11200,8300
# 019,Reel,270,1400,80,90,25000,22000
# 020,Carousel,470,850,110,170,14000,10500
# Out:
# Writing data.mp3.csv
