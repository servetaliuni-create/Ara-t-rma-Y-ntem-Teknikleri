# %% [markdown]
# # Final Project: Sosyal Medya (Instagram vb.) Akış(keşfet vb) Algoritması Mantığı (Nelere göre çalıştığı) ve İşleyiş Süreci
# **Ad Soyad:** [Servet Ali Toprak]
# **Ders:** [Araştırma Yöntem Teknikleri]
#
# Bu proje, MP1'den MP5'e kadar olan tüm aşamaların birleşimidir. Instagram üzerinde 0'dan 260.000 takipçiye ulaşan bir hesabın büyüme verileri, algoritmik tersine mühendislik yöntemleri ve nöro-pazarlama stratejileri analiz edilmiştir.

# %% [markdown]
# ---

# %% [markdown]
# # MP1: Sosyal Medya Algoritmaları - Problem Tanımı ve Amaç
#
# ## 1. Konu Tanımı ve Önemi
# Bu çalışma, Instagram gibi milyarlarca kullanıcısı olan sosyal medya platformlarının, kullanıcılara gösterilecek içerikleri (gönderi, Reels, hikâye) hangi kriterlere göre seçtiğini ve sıraladığını yöneten algoritmik sistemleri incelemektedir.
#
# * Bu araştırma, Instagram gibi milyarlarca kullanıcılı sosyal medya platformlarının, kullanıcılara gösterilecek içerikleri (Akış, Keşfet, Reels) hangi kriterlere göre seçtiğini ve sıraladığını yöneten algoritmik sistemleri incelemektedir.
# * Bu algoritmalar, milyarlarca insanın bilgiye erişimini, tüketim alışkanlıklarını ve toplumsal etkileşimini doğrudan şekillendiren "görünmez" bir kürasyon gücüdür.
#
# ## 2. Seçim Nedeni
# Bu konu, dijital çağda bilgiye erişimimizi, tüketim alışkanlıklarımızı ve hatta kamuoyunu doğrudan şekillendiren "görünmez" bir güç olduğu için seçilmiştir.
#
# ## 3. Problem Tanımı ve Bilinmeyenler
#
# ### Bilinmeyen I ve Çalışma Amacı
# Bu sunumda konu 2 aşamada ele alınacaktır. İlki içerik üretici gözünden sorulan sorudur. Instagram algoritmasının temel çalışma prensipleri genel hatlarıyla bilinse de, içerik üreticileri ve kullanıcılar için en büyük sorun bu algoritmanın hangi etkileşim sinyalinin (beğeni, yorum, kaydetme, paylaşım) ne kadar etki ettiğinin belirsizliğidir.
#
# Görsel üzerindeki yazıların konumu, renk seçimleri ve ses tercihlerinin bir içerikteki öneminin belirlenmesi ve içeriğin istatistiki değerlerinin bize neleri anlattığı sunumun konusu olacaktır. Bir içeriğin viral olmasını veya geniş kitlelere ulaşmasını tetikleyen en kritik faktörün hangisi olduğu net değildir.
#
# **Çözülmesi gereken sorun şudur:** "Bir içeriğin organik erişimini maksimize etmede belirleyici faktörler nelerdir?"
#
# ### Bilinmeyen II (Tüketici Tarafı)
# 2. olarak ele alınacak konu içeriğin içerik tüketici tarafından görülen tarafıdır. Burada da içerik üreticinin elinde olmayan ama akışa etki eden diğer faktörler ele alınacaktır. Kişinin daha önce yaptığı ve o uygulamaya ait olmayan verilerin kullanılıp kullanılmadığı (Örneğin Google'da yaptığı bir aramanın Instagram'daki algoritmaya etki edip etmediği veya sesli olarak dile getirdiği bir söylemin dinlenerek Instagram'da karşısına çıkıyor olup olmadığı vb.) ele alınacaktır.
#
# ---
#
# # MP2: Literatür Taraması ve Değişkenler
#
# ## 1. Temel Kavramlar
# * **Algoritmik Kürasyon (Algorithmic Curation):** İçeriğin kronolojik (zaman sırasına göre) değil, makine öğrenimi modelleri kullanarak kullanıcının "ilgi düzeyine" göre sıralanması ve filtrelenmesi süreci.
# * **Etkileşim Sinyalleri (Engagement Signals):** Kullanıcıların yaptığı (beğeni, yorum, kaydetme, paylaşım, izleme süresi gibi) ve algoritmaya içeriğin kalitesi ve alaka düzeyi hakkında bilgi veren eylemler.
# * **Organik Erişim (Organic Reach):** Bir içeriğin, ücretli tanıtım olmaksızın ulaştığı benzersiz kullanıcı sayısı. (Araştırmamızın temel bağımlı değişkenlerinden biri).
# * **Platform Dışı Veri (Off-Platform Data):** Bir sosyal medya platformunun, kullanıcının diğer web sitelerindeki (örn. Google aramaları, e-ticaret siteleri) veya diğer uygulamalardaki aktivitelerinden topladığı veriler.
# * **Araştırma Boşluğu (Research Gap):** Literatürde henüz yeterince cevaplanmamış veya eksik bırakılmış araştırma alanı.
#
# ## 2. Araştırma Değişkenleri
#
# ### Bağımsız Değişkenler (Etkileyen/Test Edilen Faktörler)
# * **Etkileşim Sinyalleri:** Beğeni Sayısı, Yorum Sayısı, Kaydetme Sayısı, Paylaşım Sayısı.
# * **İçerik Formatı:** Reels, Carousel (Çoklu Fotoğraf), Tek Görsel. Portre veya kare şekil.
# * **Görsel Tasarım Unsurları:** Metin Konumu (örn: ekranın ortası vs. altı), Renk Paleti (örn: yüksek kontrastlı vs. pastel tonlar), Kapak Fotoğrafı Seçimi.
# * **Ses Tercihi:** Trend Ses Kullanımı, Orijinal Ses Kullanımı.
# * **Platform Dışı Web Aktivitesi:** Google vb. arama motorlarında yapılan spesifik aramalar (örn: "Japonya uçak bileti" araması).
# * **Platform Dışı Sesli Konuşma:** Cihaz mikrofonu yakınında yapılan spesifik konulu sohbetler (örn: "yeni bir kahve makinesi" hakkında konuşmak).
# * **Diğer Uygulama Verileri:** Meta ekosistemi dışındaki uygulamalarda (örn: e-ticaret siteleri) gezilen ürünler.
#
# ### Bağımlı Değişkenler (Ölçülen Sonuç)
# * Gönderinin **"Organik Erişimi"** (Özellikle "Takipçi Dışı Kitlelerden Gelen Erişim" ve "Keşfet'ten Gelen Erişim" metrikleri).
# * Gönderinin **"Etkileşim Oranı"** (Toplam etkileşimlerin erişime bölünmesi).
# * Kullanıcının Instagram akışında (Ana Sayfa, Keşfet, Reels) karşılaştığı **"İlgili Konudaki İçerik/Reklam Sıklığı"**.
# * İlgili içeriğin ortaya çıkma **"Hızı"** (Dışsal aktiviteden ne kadar süre sonra göründüğü).

# %% [markdown]
# # MP2: Literatür Taraması ve Değişkenler
#
# ## 1. Temel Kavramlar
# * **Algoritmik Kürasyon (Algorithmic Curation):** İçeriğin kronolojik değil, makine öğrenimi modelleri ile kullanıcının "ilgi düzeyine" göre sıralanması.
# * **Etkileşim Sinyalleri (Engagement Signals):** Algoritmaya kalite sinyali veren kullanıcı eylemleri (Beğeni, Yorum, Kaydetme, Paylaşım, İzleme Süresi).
# * **Organik Erişim (Organic Reach):** Ücretli reklam olmadan ulaşılan benzersiz kullanıcı sayısı.
# * **Platform Dışı Veri (Off-Platform Data):** Kullanıcının diğer uygulamalardaki (Google, E-ticaret) ayak izlerinin sosyal medya platformu tarafından toplanması.
# * **Araştırma Boşluğu (Research Gap):** Literatürde "Kaydetme" eyleminin "Beğeni"ye göre nicel katsayısının (Örn: 1 Kaydetme = X Beğeni) akademik olarak tanımlanmamış olması.
#
# ## 2. Araştırma Değişkenleri
#
# ### Bağımsız Değişkenler (Etkileyen Faktörler)
# **A. İçsel Faktörler (İçerik Özellikleri):**
# * **Etkileşim Sinyalleri:** Beğeni, Yorum, Kaydetme, Paylaşım sayıları.
# * **İçerik Formatı:** Reels, Carousel, Tek Görsel (4:5 Portre veya 1:1 Kare).
# * **Görsel Tasarım:** Metin konumu, Renk paleti (Kontrast/Pastel), Kapak fotoğrafı.
# * **Ses Tercihi:** Trend Ses vs. Orijinal Ses.
#
# **B. Dışsal Faktörler (Kullanıcı Verisi):**
# * **Platform Dışı Web Aktivitesi:** Spesifik Google aramaları (Örn: "Japonya uçak bileti").
# * **Platform Dışı Sesli Konuşma:** Mikrofon yakınında yapılan spesifik sohbetler.
# * **Diğer Uygulama Verileri:** E-ticaret sitelerinde gezilen ürünler.
#
# ### Bağımlı Değişkenler (Ölçülen Sonuçlar)
# * **Organik Erişim:** Takipçi dışı kitlelerden ve Keşfet'ten gelen erişim miktarı.
# * **Etkileşim Oranı:** (Toplam Etkileşim / Toplam Erişim) * 100.
# * **İçerik Sıklığı:** İlgili konudaki içeriğin/reklamın akışta çıkma sıklığı.
# * **Hız:** İlgili içeriğin dışsal aktiviteden ne kadar süre sonra göründüğü.
#
# ## 3. Literatür Özeti (Tablo)
#
# | Yazar ve Yıl | Yöntem / Kaynak | Veri Türü | Elde Edilen Temel Sonuç |
# | :--- | :--- | :--- | :--- |
# | **Instagram (Resmi Blog) [1]** | Algoritma Şeffaflık Raporu | Sinyal Kategorileri | Keşfet sayfası için en kritik sinyaller "Kaydetme" ve "Paylaşma"dır. |
# | **Kolsquare (2025) [2]** | Sektör Analizi | Platform Trendleri | "Kaydetme", kullanıcının tekrar bakma niyetini gösteren güçlü bir sinyaldir; eğitimsel içerikler bu yüzden avantajlıdır. |
# | **Zuboff, S. (2019) [3]** | Teorik Analiz (Kitap) | İş Modelleri / Patentler | "Gözetim Kapitalizmi": Platformlar davranışsal verileri toplayarak "tahmin ürünleri" oluşturur ve satar. |
# | **Dogan, V. (2024) [4]** | Nitel Araştırma | Gizlilik Politikaları | Platformlar, kişiselleştirme için platform dışı verileri şeffaf olmayan yollarla işlemektedir. |
